# %%
while True:
    pergunta = input("Qual o seu número?")
    crush = "11 972702554"
    if pergunta == crush :
        print("Uii, o mesmo número 😄")
        break
    else:
        print("Número errado")
# Out:
# Número errado
# Número errado
# Uii, o mesmo número 😄

# %%
while True:
    pergunta = input("Qual o seu nome completo ?")
    crush = "Leonardo Martins Soares"
    if pergunta == crush :
        print("Uii, o mesmo nome 😄")
        break
    else:
        print("Nome errado")
# Out:
# Nome errado
# Uii, o mesmo nome 😄

# %%
numero = int(input("Digite um número:"))
anterior = numero - 1
superior = numero + 1
print(f"O número  que você escolheu foi {numero}, o anterior é {anterior} e o superior é {superior}")
# Out:
# O número  que você escolheu foi 6, o anterior é 5 e o superior é 7

# %%
numero = int(input("Digite um número:"))
for i in range(numero + 1):
    print("Número:", i)
# Out:
# Número: 0
# Número: 1
# Número: 2
# Número: 3
# Número: 4

# %%
quantidades_contatinhos = int(input("Quantos contatinhos você tem ?"))
for i in range(quantidades_contatinhos):
    nomes_contatinhos = input("Quais os nomes desses contatinhos ?")
    print(nomes_contatinhos)
# Out:
# pai
# mãe

# %%
quantidades_hobbies = int(input("Quantos hobbies você tem ?"))
for i in range(quantidades_contatinhos):
    nomes_hobbies = input("Quais os nomes desses hobbies ?")
    print(nomes_hobbies)
# Out:
# jogar bola
# ficar com a família

# %%
quantidades_notas= int(input("Quantas notas você tem?"))

for i in range(quantidades_notas):
    notas = float(input(f"Me fale as notas {i+1}:"))
    
    if notas > 7:
        print("Boa !!!")
    else:
        print("Sou imune ao conhecimento")
# Out:
# Sou imune ao conhecimento
# Boa !!!
# Sou imune ao conhecimento
# Sou imune ao conhecimento
# Sou imune ao conhecimento

# %%
quantidades_produtos = int(input("Quantos produtos você deseja comprar ?"))

for i in range (quantidades_produtos):
    nome = input("Qual o nome do produto ?")
    preco = float(input("Qual o preço dos produto"))

    if preco > 50:
        print(f"Está caro")

    elif  40<= preco <= 45:
        print(f"Está ok")

    else:
        print(f"Baratinho até o motoboy compra")
# Out:
# Baratinho até o motoboy compra
# Está ok
